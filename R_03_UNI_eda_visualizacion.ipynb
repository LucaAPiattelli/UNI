# %% [markdown]
# <a href="https://colab.research.google.com/github/LucaAPiattelli/UNI/blob/main/R_03_UNI_eda_visualizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ![Captura de Pantalla 2021-08-16 a la(s) 23.25.35.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# <center>
# <font color="#091f60">
# <h1><b>
# Dirección de Estudios de Posgrado y Educación Continua
# <h2><b>
# Analítica Avanzada con Power BI, R y Python
# </font>
# </center>

# %% [markdown]
# [UNI-DEPEC](https://posgrado.uni.edu.ni)

# %% [markdown]
# <font color="#091f60">
# <h1><b>
# Análisis Exploratorio de Datos
# </font>

# %% [markdown]
# # Visualizaciones de Datos - Librería ggplot2

# %% [markdown]
# ![ggplot2](https://lh3.googleusercontent.com/proxy/SIwsDOsIsf8L2fcUM_a8bcnPBfBntTX1bR9qcyNAPxshpt_ni2Oo5EzERGr21Swemdsi0Lo1HZQk0bUCtC0r1rSiGgr0Bysw)

# %% [markdown]
# **ggplot2** es la librería predilecta utilizada en R, ya que es elegante y versatil.
#
# **ggplot2** utiliza una *gramática de gráficos*, podríamos decir que:
#
# un gráfico = theme + coordinates + facets + geometries + scales + statistics + mapping + data
#
# 1. Data: son los datos a graficar
# 2. Aesthetics: es el mapeo de los elementos (qué queremos graficar) y los elementos estéticos como color, forma tamaño
# 3. Geometries: determina el tipo de visualización (barras, puntos, líneas)
# 4. Facets: divisiones de los gráficos en subconjuntos
# 5. Statistics: permiten transformar los datos (media, cuartil, mediana)
# 6. Coordinates: transformaciones en el espacio y características de los ejes
# 7. Themes: temas como el color, encabezado, tamaño ejes
#
# Donde los escenciales son: *Data, Aesthetics, Geometries*

# %% [markdown]
# ## Carga de librerías necesarias

# %%
install.packages("viridis")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘gridExtra’

# %%
library(tidyverse)
library(viridis)

# %% [markdown]
# ## Extracción de Datos - Creación del tibble

# %% [markdown]
# El conjunto de datos *mpg* nos permite ver:
#
# * manufacturer: fabricante
# * model: nombre del modelo
# * displ: litros del motor
# * year: año de fabricación
# * cyl: número de cilindros
# * trans: tipo de transmisión
# * drv: tipo de tracción (f-frontal, r-trasera, 4dw-4x4)
# * cty: eficiencia del motor en ciudad (millas por galón
# * hwy: eficiencia del motor en carretera (millas por galón)
# * fl: tipo de combustible
# * class: tipo de auto

# %%
mpg <- mpg

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
mtcars <- mtcars
airquality <- airquality
rock <- rock
sleep <- sleep

# %% [markdown]
# ## Creación de gráficos

# %%
options(repr.plot.width=12, repr.plot.height=6)

# %% [markdown]
# Si creamos un gráfico solo con los datos, no se visualiza nada, ya que no hemos definido ni geometría ni estética

# %%
ggplot(data = mpg)
# Out:
# plot without title

# %% [markdown]
# Para sumar elementos a un gráfico se utiliza el signo *"+"*
#
# La geometría se define con:
# * geom_point: gráfico de puntos
# * geom_line: gráfico de línea
# * geom_bar y col: gráficos de barras
# * geom_boxplot: gráfico de boxplot
# * geom_density: gráfico de densidad
# * geom_histogram: gráfico de histograma
#
# [Más información](https://ggplot2.tidyverse.org/reference/index.html)

# %% [markdown]
# [Paleta de colores en ggplot2](https://www.r-graph-gallery.com/ggplot2-color.html)

# %% [markdown]
# La sintaxis a utilizar es:
#
#
#
# ```
# ggplot(data = <DATOS>) +
#   FUNCIÓN GEOMETRÍA(mapping = FUNCIÓN ESTÉTICA(<MAPEOS>))
# ```
#
#
#
# En este caso elegímos un gráfico de puntos y luego definimos el *"mapeo"* en el cual definimos la estética

# %%
ggplot(data = mpg) +
  geom_point() + 
  aes(x = displ, y = hwy)
# Out:
# plot without title

# %% [markdown]
# Realizamos el gráfico pero daando color por la clase

# %%
ggplot(data = mpg) +
  geom_point() + 
  aes(x = displ, y = hwy, color = class)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point() + 
  aes(x = displ, y = hwy, color = class, size = hwy)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point() +
  aes(x = displ, y = hwy, alpha = hwy)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point() + 
  aes(x = displ, y = hwy, shape = class)
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(color = "steelblue1") +
  aes(x = displ, y = hwy, size = hwy)
# Out:
# plot without title

# %% [markdown]
# ### facet

# %%
ggplot(data = mpg) +
  geom_point() +
  aes(x = displ, y = hwy) + 
  facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %% [markdown]
# La geometría smooth nos permite elegir:
#
# * lm: suavización lineal
# * glm: suavización lineal generalizada
# * loess: suaviazación polinómica

# %%
ggplot(data = mpg) +
  geom_point(color = "steelblue1") +
  aes(x = displ, y = hwy) +
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(color = "steelblue1") +
  aes(x = displ, y = hwy) +
  geom_smooth(method = lm)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  aes(class, cty) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  aes(class, cty) +
  geom_boxplot(outlier.colour = "black", outlier.shape = 1)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  aes(cty) +
  geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(data = mpg) + 
  aes(cty) +
  geom_histogram(binwidth = 2)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  aes(cty) +
  geom_histogram(binwidth = 2)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  aes(cty, fill = class) +
  geom_histogram(binwidth = 2) +
  facet_wrap(~class, ncol = 2)
# Out:
# plot without title

# %% [markdown]
# ## Gráficos de distribución

# %% [markdown]
# ### Violin

# %% [markdown]
# Los gráficos de violin permiten visualizar la distribución de una variable numérica para uno o muchos grupos. Si se crean horizontalmente es mejor para poder leer las etiquetas de las variables

# %% [markdown]
# El parámetro fill = name nos permite asignar un color en base a una columna determinada

# %%
data <- data.frame(
  name=c( rep("A",500), rep("B",500), rep("B",500), rep("C",20), rep('D', 100)  ),
  value=c( rnorm(500, 10, 5), rnorm(500, 13, 1), rnorm(500, 18, 1), rnorm(20, 25, 4), rnorm(100, 12, 1) )
)
ggplot(data = data) +
  aes(x=name, y=value, fill=name) +
  geom_violin()
# Out:
# plot without title

# %%
data %>%
  ggplot() +
  aes(x=name, y=value, fill=name, color=name) + 
  geom_violin(width=2.1, size=0.2) +
  scale_fill_viridis(discrete=TRUE) +
  scale_color_viridis(discrete=TRUE) +
  coord_flip()
# Out:
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# plot without title

# %% [markdown]
# ### Cambiar el orden

# %% [markdown]
# el parámetro stat = "identity" en un gráfico de barras, significa que por defecto estos gráficos hacen el conteo de los valores de x, especificando identity le decimos que utilice los valores de y

# %%
data <- data.frame(
  name=c("north","south","south-east","north-west","south-west","north-east","west","east"),
  val=sample(seq(1,10), 8 )
)

data %>%
  mutate(name = fct_reorder(name, val)) %>%
  ggplot() +
  aes(x=name, y=val) +
  geom_bar(stat="identity", fill="#f68060", alpha=.6, width=.4) +
  coord_flip()
# Out:
# plot without title

# %%
data %>%
  mutate(name = fct_reorder(name, desc(val))) %>%
  ggplot() +
  aes(x=name, y=val) +
  geom_bar(stat="identity", fill="#f68060", alpha=.6, width=.4) +
  coord_flip()
# Out:
# plot without title

# %% [markdown]
# Ordenar según un orden específico

# %%
data %>%
  mutate(name = fct_relevel(name, 
                            "north", "north-east", "east", 
                            "south-east", "south", "south-west", 
                            "west", "north-west")) %>%
  ggplot( aes(x=name, y=val)) +
  geom_bar(stat="identity")
# Out:
# plot without title

# %% [markdown]
# ### Densidad

# %% [markdown]
# Un gráfico de densidad muestra la distribución de una variable numérica. Generalmente se suele utilizar para comparar la distribución de varios grupos

# %%
data <- read.table("https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/1_OneNum.csv", header=TRUE)

data %>%
  filter( price<300 ) %>%
  ggplot() +
    aes(x=price) +
    geom_density(fill="#69b3a2", color="#e9ecef", alpha=0.8)
# Out:
# plot without title

# %%
data <- diamonds

ggplot(data=data) +
  aes(x=price, group=cut, fill=cut) +
  geom_density()
# Out:
# plot without title

# %%
ggplot(data=data) +
  aes(x=price, group=cut, fill=cut) +
  geom_density(alpha = 0.4)
# Out:
# plot without title

# %%
ggplot(data=data) +
  aes(x=price, group=cut, fill=cut) +
  geom_density() +
  facet_wrap(~cut)
# Out:
# plot without title

# %%
ggplot(data=data) +
  aes(x=price, group=cut, fill=cut) +
  geom_density(position ="fill")
# Out:
# plot without title

# %% [markdown]
# ### Histograma

# %% [markdown]
# El gráfico de histograma muestra la distribuciín de una variable numérica en grupos y la cantidad de valores en cada grupo

# %%
data=data.frame(value=rnorm(100))

# %%
ggplot(data = data)+
  aes(x = value) +
  geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# Binwidth nos permite controlar el tamaño de cada grupo, en este caso de 0.5 en 0.5

# %%
ggplot(data = data)+
  aes(x = value) +
  geom_histogram(binwidth=0.5, fill="#69b3a2", color="#e9ecef", alpha=0.9)
# Out:
# plot without title

# %%
data <- data.frame(
  type = c( rep("variable 1", 1000), rep("variable 2", 1000) ),
  value = c( rnorm(1000), rnorm(1000, mean=4) )
)

ggplot(data = data) +
  aes(x = value, fill = type) +
  geom_histogram(color="#e9ecef", alpha=0.6, position = 'identity')
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(data = data) +
  aes(x = value, fill = type) +
  geom_histogram(color="#e9ecef", alpha=0.6) +
  facet_wrap(~type)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ### Boxplot

# %% [markdown]
# El gráfico boxplot es un gráfico para comparar la distribución entre diferentes grupos ya que nos muestra:
#
# * rango
# * outliers
# * rango intercuartil
# * cuartiles
# * mediana
# * mínimo
# * máximo

# %%
data <- data.frame(
  name=c( rep("A",500), rep("B",500), rep("B",500), rep("C",20), rep('D', 100)  ),
  value=c( rnorm(500, 10, 5), rnorm(500, 13, 1), rnorm(500, 18, 1), rnorm(20, 25, 4), rnorm(100, 12, 1) )
)

ggplot(data = data) +
  aes(x = name, y = value, fill = name) +
  geom_boxplot() +
  ggtitle("Basic boxplot")
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = name, y = value, fill = name) +
  geom_boxplot(
    # Modificar cajas
    color="blue",
    fill="blue",
    alpha=0.2,
    # Modificar outliers
    outlier.colour="red",
    outlier.fill="red",
    outlier.size=7
  ) +
  ggtitle("Basic boxplot")
# Out:
# plot without title

# %%
mpg <- mpg

mpg %>%
mutate(type=ifelse(class=="subcompact","Highlighted","Normal")) %>%
ggplot() +
  aes(x = class, y = hwy, fill = type) +
  geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# ## Gráficos de Correlación

# %% [markdown]
# ### Distribución

# %% [markdown]
# Crea un gráfico donde se muestra la relación entre dos variables numéricas, cada punto representa una observación

# %%
iris <- iris

ggplot(data = iris) +
  aes(x = Sepal.Length, y = Sepal.Width) +
  geom_point()
# Out:
# plot without title

# %% [markdown]
# Temas en ggplot

# %%
ggplot(data = iris) +
  aes(x = Sepal.Length, y = Sepal.Width) +
  geom_point() +
  theme_gray()
  # theme_bw()
  # theme_linedraw()
  # theme_light()
  # theme_dark()
  # theme_minimal()
  # theme_clasic()
  # theme void()
  # theme_test()
# Out:
# plot without title

# %%
ggplot(data = iris) +
  aes(x=Sepal.Length, y=Sepal.Width) + 
  geom_point(
    color="orange",
    fill="#69b3a2",
    shape=21,
    alpha=0.5,
    size=6,
  )
# Out:
# plot without title

# %%
ggplot(data = iris) +
  aes(x=Sepal.Length, y=Sepal.Width, color = Species) + 
  geom_point(
    alpha=0.5,
    size=6,
  )
# Out:
# plot without title

# %% [markdown]
# Agregar etiquetas

# %%
data <- head(mtcars, 20)
data
# Out:
#                     mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# Mazda RX4           21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag       21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# Datsun 710          22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive      21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout   18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# Valiant             18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# Duster 360          14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# Merc 240D           24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# Merc 230            22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# Merc 280            19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# Merc 280C           17.8 6   167.6 123 3.92 3.440 18.90 1  0  4    4
# Merc 450SE          16.4 8   275.8 180 3.07 4.070 17.40 0  0  3    3
# Merc 450SL          17.3 8   275.8 180 3.07 3.730 17.60 0  0  3    3
# ...

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  geom_text(
    label = rownames(data),
    check_overlap = T,
    nudge_x = 0.25, nudge_y = 0.25, 
  )
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  geom_text(
    label = rownames(data),
    check_overlap = T,
    nudge_x = 0.25, nudge_y = 0.25, 
  ) +
  geom_label(
    label="Aprendiendo ggplot2 !", 
    x=4.5,
    y=25,
    label.padding = unit(1, "lines"),
    label.size = 0.35,
    color = "black",
    fill="#69b3a2"
  )
# Out:
# plot without title

# %% [markdown]
# Agregar tendencias, se es el intervalo de confianza

# %%
data <- data.frame(
  cond = rep(c("condition_1", "condition_2"), each=10), 
  my_x = 1:100 + rnorm(100,sd=9), 
  my_y = 1:100 + rnorm(100,sd=16) 
)

ggplot(data = data) +
  aes(x = my_x, y = my_y) +
  geom_point(color="#69b3a2") +
  geom_smooth(method = lm, color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# ### Correlograma

# %% [markdown]
# Permite analizar la corelación para cada par de variables numéricas

# %%
install.packages("GGally")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘reshape’

# %%
library(GGally)
# Out:
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
data <- data.frame( var1 = 1:100 + rnorm(100,sd=20), v2 = 1:100 + rnorm(100,sd=27), v3 = rep(1, 100) + rnorm(100, sd = 1)) 
data$v4 = data$var1 ** 2 
data$v5 = -(data$var1 ** 2) 

ggcorr(data, method = c("everything", "pearson"))
# Out:
# plot without title

# %%
ggpairs(data)
# Out:
# plot without title

# %% [markdown]
# ### Burbujas

# %%
install.packages("gapminder")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(gapminder)
data <- gapminder %>% filter(year=="2007") %>% dplyr::select(-year)

ggplot(data = data) +
  aes(x=gdpPercap, y=lifeExp, size = pop) +
  geom_point(alpha=0.7)
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x=gdpPercap, y=lifeExp, size = pop) +
  geom_point(alpha=0.7) +
  scale_size(range = c(.1, 24))
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x=gdpPercap, y=lifeExp, size = pop, color=continent) +
  geom_point(alpha=0.7) +
  scale_size(range = c(.1, 24))
# Out:
# plot without title

# %% [markdown]
# ## Gráficos de Ranking

# %% [markdown]
# ### Barras

# %% [markdown]
# Este tipo de gráficos es utilizado para mostrar la relación entre una variable numérica y una variable categórica

# %%
data <- data.frame(
  name=c("A","B","C","D","E") ,  
  value=c(3,12,5,18,45)
)

ggplot(data = data) +
  aes (x = name, y = value) +
  geom_bar(stat = "identity")
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes (x = name, y = value) +
  geom_bar(stat = "identity") +
  coord_flip()
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes (x = name, y = value) +
  geom_bar(stat = "identity", width = 0.5)
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes (x = name, y = value) +
  geom_bar(stat = "identity")
# Out:
# plot without title

# %% [markdown]
# Barras por grupo

# %%
specie <- c(rep("banana" , 3) , rep("mandarina" , 3) , rep("naranja" , 3) , rep("pomelo" , 3) )
condition <- rep(c("Vitamina C" , "Potacio" , "Azucar") , 4)
value <- abs(rnorm(12 , 0 , 15))
data <- data.frame(specie,condition,value)

ggplot(data = data) +
  aes(fill = condition, y = value, x = specie) +
  geom_bar(position = "dodge", stat = "identity")
# Out:
# plot without title

# %% [markdown]
# Barras apiladas

# %%
ggplot(data = data) +
  aes(fill = condition, y = value, x = specie) +
  geom_bar(position = "stack", stat = "identity")
# Out:
# plot without title

# %% [markdown]
# Barras apiladas al 100%

# %%
ggplot(data = data) +
  aes(fill = condition, y = value, x = specie) +
  geom_bar(position = "fill", stat = "identity")
# Out:
# plot without title

# %% [markdown]
# ## Gráficos de evolución

# %% [markdown]
# ### Líneas

# %%
xvalue <- 1:10
yvalue <- cumsum(rnorm(10))
class <- c("A","B","C","A","A","A","B","B","C","B")
data <- data.frame(xvalue,yvalue, class)

ggplot(data = data) +
  aes(x = xvalue, y = yvalue) +
  geom_line()
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = xvalue, y = yvalue) +
  geom_line(color="#69b3a2", size=2, alpha=0.9, linetype=2) +
  ggtitle("Evolución de algo")
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = xvalue, y = yvalue) +
  geom_line(color="#69b3a2", size=2, alpha=0.9, linetype=2) +
  geom_point(shape = 21, color = "black", fill = "#69b3a2", size = 4) +
  ggtitle("Evolución de algo")
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = xvalue, y = yvalue) +
  geom_line(color="#69b3a2", size=2, alpha=0.9, linetype=2) +
  geom_point(shape = 21, color = "black", fill = "#69b3a2", size = 4) +
  geom_text(
    label = round(yvalue),
    check_overlap = T,
    nudge_x = 0.10, nudge_y = 0.15
  ) +
  ggtitle("Evolución de algo")
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = xvalue, y = yvalue, group = class, color = class) +
  geom_line(size=2, alpha=0.9, linetype=2) +
  ggtitle("Evolución de algo")
# Out:
# plot without title

# %% [markdown]
# ## Etiquetas

# %% [markdown]
# Las etiquetas aportan valor y contexto a los gráficos
#
# * label: es el texto que queremos mostrar
# * nudge_x y nudge_y: son los movimientos de la etiqueta en el eje x e y
# * check_overlap: evita que se superpongan las etiquetas

# %%
data <- head(mtcars, 20)
data
# Out:
#                     mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# Mazda RX4           21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag       21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# Datsun 710          22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive      21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout   18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# Valiant             18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# Duster 360          14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# Merc 240D           24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# Merc 230            22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# Merc 280            19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# Merc 280C           17.8 6   167.6 123 3.92 3.440 18.90 1  0  4    4
# Merc 450SE          16.4 8   275.8 180 3.07 4.070 17.40 0  0  3    3
# Merc 450SL          17.3 8   275.8 180 3.07 3.730 17.60 0  0  3    3
# ...

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  geom_text(
    label = rownames(data),
    check_overlap = T,
    nudge_x = 0.25, nudge_y = 0.25, 
  )
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  geom_label(
    label = rownames(data),
    check_overlap = T,
    nudge_x = 0.25, nudge_y = 0.25, 
  )
# Out:
# Warning message:
# “Ignoring unknown parameters: check_overlap”
# plot without title

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  geom_text(
    label = rownames(data),
    check_overlap = T,
    nudge_x = 0.25, nudge_y = 0.25, 
  ) +
  geom_label(
    label="Aprendiendo ggplot2 !", 
    x=4.5,
    y=25,
    label.padding = unit(1, "lines"),
    label.size = 0.35,
    color = "black",
    fill="#69b3a2"
  )
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  annotate(
    "rect",
    xmin = c(2,4),
    xmax = c(3,5),
    ymin = c(20,10),
    ymax = c(30,20),
    alpha = 0.2,
    color = "blue",
    fill = "blue"
  )
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  annotate(
    "segment", 
    x = 1, 
    xend = 3, 
    y = 25, 
    yend = 15, 
    colour = "purple", 
    size=3, 
    alpha=0.6
  )
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  annotate(
    "segment", 
    x = 4.5, 
    xend = 5.3, 
    y = 25, 
    yend = 15, 
    colour = "purple", 
    size=3, 
    alpha=0.6,
    arrow = arrow()
  )
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = wt, y = mpg) +
  geom_point() +
  geom_hline(yintercept=25, color="orange", size=1) + 
  geom_vline(xintercept=3, color="orange", size=1)
# Out:
# plot without title

# %% [markdown]
# ## Ejes

# %%
?mtcars
# Out:
# Warning message in seq_len(head.end.idx):
# “first element used of 'length.out' argument”
# ERROR while rich displaying an object: Error in seq_len(head.end.idx): argument must be coercible to non-negative integer
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
# ...

# %% [markdown]
# Gráfico básico

# %%
ggplot(data = data) +
  aes(x = mpg, y = wt) +
  geom_point()
# Out:
# plot without title

# %% [markdown]
# Título y límite de eje

# %%
ggplot(data = data) +
  aes(x = mpg, y = wt) +
  geom_point() +
  xlab("Millas por Galón") +
  xlim(0,40)
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = mpg, y = wt) +
  geom_point() +
  xlab("Millas por Galón") +
  xlim(0,40) +
  ylab("Peso del Vehículo") +
  ylim(0,7) +
  ggtitle("Millas por Galón según el peso del Vehículo")
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = mpg, y = wt) +
  geom_point() +
  xlab("Millas por Galón") +
  xlim(0,40) +
  ylab("Peso del Vehículo") +
  ylim(0,7) +
  ggtitle("Millas por Galón según el peso del Vehículo") +
  theme(
    axis.title.y = element_text( angle = 90, color="black", size=15),
    axis.title.x = element_text(color="black", size=15),
    title = element_text(color = "black", size = 21)
  )
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = mpg, y = wt) +
  geom_point() +
  annotate(
    "rect",
    xmin = 29.5,
    xmax = 35,
    ymin = 1.3,
    ymax = 2.5,
    alpha = 0.2,
    color = "blue",
    fill = "blue"
  ) +
  geom_label(
    label="Mejores rendimientos", 
    x=32,
    y=3.3,
    label.padding = unit(1, "lines"),
    label.size = 0.35,
    color = "black",
    fill="#69b3a2"
  ) +
  xlab("Millas por Galón") +
  xlim(7,38) +
  ylab("Peso del Vehículo") +
  ylim(0,7) +
  ggtitle("Millas por Galón según el peso del Vehículo") +
  theme(
    axis.title.y = element_text( angle = 90, color="black", size=15),
    axis.title.x = element_text(color="black", size=15),
    title = element_text(color = "black", size = 21)
  )
# Out:
# plot without title

# %%
ggplot(data = data) +
  aes(x = mpg, y = wt) +
  geom_point(color="#22577A", alpha = 0.5, size = 3) +
  annotate(
    "rect",
    xmin = 29.5,
    xmax = 35,
    ymin = 1.3,
    ymax = 2.5,
    alpha = 0.2,
    color = "#6F69AC",
    fill = "#6F69AC"
  ) +
  geom_label(
    label="Mejores rendimientos", 
    x=32.18,
    y=3.3,
    label.padding = unit(1, "lines"),
    label.size = 0.35,
    color = "black",
    fill="#69b3a2"
  ) +
  xlab("Millas por Galón") +
  xlim(7,38) +
  ylab("Peso del Vehículo") +
  ylim(0,7) +
  ggtitle("Millas por Galón según el peso del Vehículo") +
  theme(
    axis.title.y = element_text( angle = 90, color="black", size=15),
    axis.title.x = element_text(color="black", size=15),
    title = element_text(color = "black", size = 21)
  )
# Out:
# plot without title

# %% [markdown]
# # Seras el próximo ggpicasso?

# %%
install.packages(c("sp","rgeos"))
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("dplyr")
library("ggplot2")
library("sp")
library("rgeos")


# Funs --------------------------------------------------------------------

coord_circle <- function(centre = c(0, 0), r = 1, n = 1000) {
  data_frame(
    x = seq(from = 0 - r, to = 0 + r, length.out = n %/% 2),
    y = sqrt(r^2 - x^2)
  ) %>% bind_rows(., -.) %>%
    mutate(x = x + centre[1], y = y + centre[2])
}


create_poly <- function(...) {
  args <- list(...)
  SpatialPolygons(
    lapply(
      X = seq_along(args),
      FUN = function(x) {
        Polygons(list(Polygon(as.data.frame(args[[x]]))), names(args)[x])
      }
    )
  )
}


echancrure <- function(to_var, by_var, p = 0.1) {
  ind <- which(by_var >= -0.08 & by_var <= 0.08 & to_var > 0)
  to_var[ind] <- to_var[ind] - p
  ind <- which(by_var >= -0.08 & by_var <= 0.08 & to_var < 0)
  to_var[ind] <- to_var[ind] + p
  return(to_var)
}



# BB-8 geometries ---------------------------------------------------------


# droid_body -------------------------------------------------------------------

# shape of the droid_body : two circles and a vertical line
droid_body <- coord_circle(centre = c(0, 0), r = 1)
droid_body$xvert <- 0
droid_body$yvert <- droid_body$x
droid_body <- bind_cols(
  droid_body,
  coord_circle(centre = c(0, 0), r = 0.35, n = nrow(droid_body)) %>% select(xint = x, yint = y)
)

# grey shapes in the central inner circle
droid_body_rect <- data_frame(
  x = c(-0.5, 0.5, 0.5, -0.5, c(-0.5, 0.5, 0.5, -0.5) - 0.2, c(-0.5, 0.5, 0.5, -0.5) + 0.2),
  y = c(-0.6, 0.4, 0.6, -0.4, c(-0.6, 0.4, 0.6, -0.4) + 0.2, c(-0.6, 0.4, 0.6, -0.4) - 0.2),
  group = rep(1:3, each = 4)
)
# a polygon for calculate the intersection between the grey shapes and the inner circle
polyrect <- create_poly(
  "polyrect1" = droid_body_rect[droid_body_rect$group == 1, 1:2],
  "polyrect2" = droid_body_rect[droid_body_rect$group == 2, 1:2],
  "polyrect3" = droid_body_rect[droid_body_rect$group == 3, 1:2]
)

polycircle <- create_poly(
  "polycircle" = droid_body[, c("xint", "yint")]
)
# plot(polyrect); plot(polycircle, add = TRUE)
polyrect <- gIntersection(spgeom1 = polyrect, spgeom2 = polycircle)
# plot(polyrect); plot(polycircle, add = TRUE)

# fortify the polygon for ggplot
droid_body_rect <- fortify(polyrect)


# Central ring (orange)
ring <- coord_circle(centre = c(0, 0), r = 0.4)
ring$y <- echancrure(to_var = ring$y, by_var = ring$x, p = 0.1)
ring$x <- echancrure(to_var = ring$x, by_var = ring$y, p = 0.1)
ring <- bind_rows(
  ring %>% mutate(group = (x >= 0) * 1),
  coord_circle(centre = c(0, 0), r = 0.55, n = nrow(ring)) %>% mutate(y = -y, group = (x >= 0) * 1)
) %>%
  filter(group == 1) # oups something went wrong
ring <- bind_rows(ring, ring %>% mutate(x = -x, group = 2))




# ring left and right
# we make a copy of the right part of the central ring
ring_left <- ring %>% filter(group == 1)
# and we shift the ring center
ring_left$x <- ring_left$x - 1.3

# the same ...
ring_right <- ring %>% filter(group == 2)
ring_right$x <- ring_right$x + 1.3

# we creta a polygon for the intersection with the droid_body circle
polyring <- create_poly(
  "polyring_g" = ring_left[, c("x", "y")],
  "polyring_d" = ring_right[, c("x", "y")]
)

polydroid_body <- create_poly("polydroid_body" = droid_body[, c("x", "y")])

# plot(polyring); plot(polydroid_body, add = TRUE)

polyring <- gIntersection(spgeom1 = polyring, spgeom2 = polydroid_body)
fort_ring <- fortify(polyring)


# the horizontal line of the body (in two parts)
ligne_hori <- data_frame(
  x = c(-1, range(ring$x), 1),
  y = 0,
  group = c(1, 1, 2, 2)
)


# droid head --------------------------------------------------------------------

droid_head <- coord_circle(centre = c(0, 1.02), r = 0.52) %>%
  filter(y >= 1.02) %>%
  mutate(group = 1, fill = "white", col= "black") %>%
  bind_rows(
    data_frame(
      x = c(-0.52, -0.4, 0.4, 0.52),
      y = c(1.02, 0.95, 0.95, 1.02),
      group = 2, fill = "white", col= "black"
    )
  )



# Grey bars in droid's head
poly_head_grey <- create_poly(
  "poly_head_grey_haut" = data_frame(
    x = c(-0.52, 0.52, 0.52, -0.52),
    y = c(1.44, 1.44, 1.51, 1.51)
  ),
  "poly_head_grey_bas" = data_frame(
    x = c(-0.52, 0.52, 0.52, -0.52),
    y = c(1.02, 1.02, 1.07, 1.07)
  )
)

polydroid_head <- create_poly("polydroid_head" = droid_head[droid_head$group == 1, c("x", "y")])

poly_head_grey <- gIntersection(spgeom1 = poly_head_grey, spgeom2 = polydroid_head)
fort_droid_headrectgris <- fortify(poly_head_grey)



# orange bars
poly_head_orange <- create_poly(
  "poly_head_orange1" = data_frame(
    x = c(-0.52, 0.52, 0.52, -0.52),
    y = c(1.38, 1.38, 1.42, 1.42)
  ),
  "poly_head_orange2" = data_frame(
    x = c(-0.35, -0.35, -0.2, -0.2),
    y = c(1.07, 1.15, 1.15, 1.07)
  ),
  "poly_head_orange3" = data_frame(
    x = c(-0.55, -0.55, -0.45, -0.45),
    y = c(1.07, 1.15, 1.15, 1.07)
  ),
  "poly_head_orange4" = data_frame(
    x = c(0.44, 0.44, 0.47, 0.47),
    y = c(1.07, 1.15, 1.15, 1.07)
  )
)

poly_head_orange <- gIntersection(spgeom1 = poly_head_orange, spgeom2 = polydroid_head)
fort_droid_headrectorange <- fortify(poly_head_orange)


polygones_droid_head <- bind_rows(
  fort_droid_headrectgris %>% select(-piece) %>%
    mutate(group = as.numeric(as.character(group)), fill = "#8E8E9C", col= "black"),
  fort_droid_headrectorange %>% select(-piece) %>% 
    mutate(group = as.numeric(as.character(group)) * 2, fill = "#DF8D5D", col= "black")
)


# Eyes
droid_eyes <- bind_rows(
  coord_circle(centre = c(0, 1.35), r = 0.14) %>% mutate(group = 1, fill = "white", col = "white"),
  coord_circle(centre = c(0, 1.35), r = 0.12) %>% mutate(group = 2, fill = "white", col = "black"),
  coord_circle(centre = c(0, 1.35), r = 0.10) %>% mutate(group = 3, fill = "grey40", col = "grey40"),
  coord_circle(centre = c(0, 1.35), r = 0.08) %>% mutate(group = 4, fill = "black", col = "black"),
  coord_circle(centre = c(0, 1.16), r = 0.04) %>% mutate(group = 5, fill = "#76B1DE", col = "black"),
  coord_circle(centre = c(0.25, 1.20), r = 0.08) %>% mutate(group = 6, fill = "black", col = "black"),
  coord_circle(centre = c(0.25, 1.20), r = 0.07) %>% mutate(group = 7, fill = "white", col = "black"),
  coord_circle(centre = c(0.25, 1.20), r = 0.06) %>% mutate(group = 8, fill = "grey40", col = "grey40"),
  coord_circle(centre = c(0.25, 1.20), r = 0.04) %>% mutate(group = 9, fill = "black", col = "black")
)

eye_line <- data_frame(
  x = 0,
  y = c(1.07, 1.16-0.04)
)

# Antennas
antennas <- data_frame(
  x = c(0.01, 0.01, 0.10, 0.10),
  y = c(sqrt(0.52^2 - 0.01^2) + 1.02, sqrt(0.52^2 - 0.01^2) + 1.02 + 0.15,
        sqrt(0.52^2 - 0.1^2) + 1.02, sqrt(0.52^2 - 0.1^2) + 1.02 + 0.25),
  group = c(1, 1, 2, 2)
)


# bb-8/ggplot2 ------------------------------------------------------------

bb8 <- ggplot(data = droid_body) +
  coord_fixed() +
  geom_polygon(mapping = aes(x = x, y = y), fill = "white", col = "black") +
  geom_polygon(data = droid_body_rect, mapping = aes(x = long, y = lat, group = group), fill = "#8E8E9C") +
  geom_path(mapping = aes(x = xvert, y = yvert)) +
  geom_path(mapping = aes(x = xint, y = yint)) +
  geom_polygon(data = ring, mapping = aes(x = x, y = y, group = group), fill = "#DF8D5D", col = "#DF8D5D") +
  geom_path(data = ligne_hori, mapping = aes(x = x, y = y, group = group)) +
  geom_polygon(data = fort_ring , mapping = aes(x = long, y = lat, group = group), fill = "#DF8D5D") +
  geom_polygon(data = droid_head, mapping = aes(x = x, y = y, group = group, fill = fill, col = col)) +
  geom_polygon(data = polygones_droid_head, mapping = aes(x = long, y = lat, group = group, fill = fill, col = col)) +
  geom_polygon(data = droid_eyes, mapping = aes(x = x, y = y, group = group, fill = fill, col = col)) +
  scale_fill_identity() + scale_color_identity() +
  geom_line(data = eye_line, mapping = aes(x = x, y = y)) +
  geom_line(data = antennas, mapping = aes(x = x, y = y, group = group), col = "black")


bb8
# or
#bb8 + theme_void()



# save --------------------------------------------------------------------

#ggsave(filename = "#144_bb8_ggplot2.png", plot = bb8, width = 6, height = 8)
#ggsave(filename = "#144_bb8_ggplot2_void.png", plot = bb8 + theme_void(), width = 6, height = 8)
# Out:
# rgeos version: 0.5-5, (SVN revision 640)
#  GEOS runtime version: 3.6.2-CAPI-1.10.2
#  Linking to sp version: 1.4-5
#  Polygon checking: TRUE
#
#
# Warning message:
# “`data_frame()` was deprecated in tibble 1.1.0.
# Please use `tibble()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# plot without title

# %%
set.seed(345)
library(ggplot2)
library(RColorBrewer)
ngroup=30
names=paste("G_",seq(1,ngroup),sep="")
DAT=data.frame()

for(i in seq(1:30)){
    data=data.frame( matrix(0, ngroup , 3))
    data[,1]=i
    data[,2]=sample(names, nrow(data))
    data[,3]=prop.table(sample( c(rep(0,100),c(1:ngroup)) ,nrow(data)))
    DAT=rbind(DAT,data)
    }
colnames(DAT)=c("Year","Group","Value")
DAT=DAT[order( DAT$Year, DAT$Group) , ]


coul = brewer.pal(12, "Paired") 
coul = colorRampPalette(coul)(ngroup)
coul=coul[sample(c(1:length(coul)) , size=length(coul) ) ]

ggplot(DAT, aes(x=Year, y=Value, fill=Group )) + 
    geom_area(alpha=1  )+
    theme_bw() +
    #scale_fill_brewer(colour="red", breaks=rev(levels(DAT$Group)))+
    scale_fill_manual(values = coul)+
     theme(
        text = element_blank(),
        line = element_blank(),
        title = element_blank(),
        legend.position="none",
        panel.border = element_blank(),
        panel.background = element_blank())
# Out:
# plot without title

# %% [markdown]
# ![UNI](https://posgrado.uni.edu.ni/wp-content/uploads/2017/02/logo_opt-2.png)
